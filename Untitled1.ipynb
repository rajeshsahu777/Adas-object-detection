# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Using cached kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in c:\users\rajesh\anaconda3\envs\adas\lib\site-packages (from kagglehub) (26.0)
# Requirement already satisfied: pyyaml in c:\users\rajesh\anaconda3\envs\adas\lib\site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in c:\users\rajesh\anaconda3\envs\adas\lib\site-packages (from kagglehub) (2.32.5)
# Collecting tqdm (from kagglehub)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rajesh\anaconda3\envs\adas\lib\site-packages (from requests->kagglehub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajesh\anaconda3\envs\adas\lib\site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rajesh\anaconda3\envs\adas\lib\site-packages (from requests->kagglehub) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajesh\anaconda3\envs\adas\lib\site-packages (from requests->kagglehub) (2026.2.25)
# Requirement already satisfied: colorama in c:\users\rajesh\anaconda3\envs\adas\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Using cached kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, kagglehub
#
#    -------------------- ------------------- 1/2 [kagglehub]
#    ---------------------------------------- 2/2 [kagglehub]
#
# Successfully installed kagglehub-0.3.13 tqdm-4.67.3

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("redzapdos123/indian-driving-dataset-detections-yolov11")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.0).
# Resuming download from 21805137920 bytes (173118373 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/redzapdos123/indian-driving-dataset-detections-yolov11?dataset_version_number=1 (21805137920/21978256293) bytes left.
# 100%|██████████████████████████████████████████████████████████████████████████████| 20.5G/20.5G [06:58<00:00, 414kB/s]
# Extracting files...
# Path to dataset files: C:\Users\Rajesh\.cache\kagglehub\datasets\redzapdos123\indian-driving-dataset-detections-yolov11\versions\1
